# %%
import pandas as pd
# Drug_info_release.csv is untinteresting
pd.read_csv("Sanger_molecular_data/cell_info.csv")
# Out:
#    Sanger.Name              CCLE.Name Alternative.Name Disease.Area  \
# 0        22RV1         22RV1_PROSTATE            22RV1      Urology
# 1        647-V     647V_URINARY_TRACT             647V      Urology
# 2         A549              A549_LUNG             A549         Lung
# 3     BFTC-905  BFTC905_URINARY_TRACT          BFTC905      Urology
# 4        BT-20            BT20_BREAST             BT20       Breast
# ..         ...                    ...              ...          ...
# 80      TCCSUP   TCCSUP_URINARY_TRACT           TCCSUP      Urology
# 81    UACC-812         UACC812_BREAST          UACC812       Breast
# 82     UM-UC-3    UMUC3_URINARY_TRACT            UMUC3      Urology
# 83        VCaP          VCAP_PROSTATE             VCAP      Urology
# 84    VM-CUB-1   VMCUB1_URINARY_TRACT           VMCUB1      Urology
#
#        Tissue..General.   COSMIC
# 0   male genital system   924100
# 1         urinary tract   906797
# 2                  lung   905949
# ...

# %%
gex = pd.read_csv("Sanger_molecular_data/gex.csv")
gex.dropna()
# Out:
#       Unnamed: 0      22RV1      647-V      A549   BFTC-905      BT-20  \
# 0         TSPAN6   4.804487   8.713556  8.495961   7.813436   7.971621
# 1           TNMD   2.848128   2.834723  2.886997   2.879330   2.792528
# 2           DPM1  10.331994  10.504748  9.643436  10.272719  10.601207
# 3          SCYL3   5.145387   3.792188  4.154471   4.050385   5.622674
# 4       C1orf112   3.545193   3.946664  3.307310   3.701491   3.740521
# ...          ...        ...        ...       ...        ...        ...
# 17414       PPY2   3.080394   3.233059  3.036383   2.970800   2.991137
# 17415   KRT18P55   3.378913   3.648132  3.259655   3.386533   3.554597
# 17416   POLRMTP1   3.191797   3.022160  2.934753   2.931548   3.168497
# 17417     UBL5P2   9.466545   9.267838  9.174437   9.781957   9.235654
# 17418   TBC1D3P5   3.214997   3.340621  3.450427   3.052209   3.299910
#
#           BT-474     BT-549       C32    CAL-120  ...      SW837      SW900  \
# ...

# %% [markdown]
# Looks like the first file contains the 85 different cell lines and and the second one 17k genes with values of their expression in all cell lines <br>
# And then we have 75k mutations with details which gene is mutated and to which tumor it led

# %%
pd.read_csv("Sanger_molecular_data/mutations.csv").iloc[1]
# Out:
# Gene.name                                                         LILRB1
# Accession.Number                                         ENST00000396331
# Gene.CDS.length                                                     1953
# HGNC.ID                                                           6605.0
# cell_line_name                                                   HCC1806
# ID_sample                                                         907047
# ID_tumour                                                         824559
# Primary.site                                                      breast
# Site.subtype                                                          NS
# Primary.histology                                              carcinoma
# Histology.subtype                                       ductal_carcinoma
# Genome.wide.screen                                                     y
# Mutation.ID                                                   COSM162161
# ...

# %% [markdown]
# CNV = Copy Number Variation

# %%
pd.read_csv("Sanger_molecular_data/cnv/cnv_segment.csv")
# Out:
#       cell_line_name  sample_id  SNPstart   SNPend chr_38 startpos_38  \
# 0           NCI-H522     905944         1    14597      1       61736
# 1           NCI-H522     905944     14598    14626      1    25266638
# 2           NCI-H522     905944     14627    17248      1    25320496
# 3           NCI-H522     905944     17249    44053      1    30457632
# 4           NCI-H522     905944     44054    44099      1    72303234
# ...              ...        ...       ...      ...    ...         ...
# 31657         KMS-11    1659817   1868236  1868488      -           -
# 31658         KMS-11    1659817   1868489  1868490      Y    56874486
# 31659         KMS-11    1659817   1868491  1868551      Y    56874769
# 31660         KMS-11    1659817   1868552  1868553      Y    56884768
# 31661         KMS-11    1659817   1868554  1868570      Y    56884775
#
#       endpos_38 chr_37  startpos_37  endpos_37  minorCN  totalCN
# ...

# %%
pd.read_csv("Sanger_molecular_data/cnv/cnv_gene.csv")
# Out:
# /home/stefanhuber3125/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3170: DtypeWarning: Columns (2,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         cell_line_name     gene chr_GRCh38  gene_start_GRCh38  \
# 0                22RV1    39340          1         86880690.0
# 1                647-V    39340          1         86880690.0
# 2                 A549    39340          1         86880690.0
# 3             BFTC-905    39340          1         86880690.0
# 4                BT-20    39340          1         86880690.0
# ...                ...      ...        ...                ...
# 2478425         TCCSUP  mir-424          X        134546614.0
# 2478426       UACC-812  mir-424          X        134546614.0
# 2478427        UM-UC-3  mir-424          X        134546614.0
# 2478428           VCaP  mir-424          X        134546614.0
# ...
